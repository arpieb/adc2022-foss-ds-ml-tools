# %% [markdown]
# # Introduce Jupyter Notebooks
#
# This is a normal Markdown cell, which is commonly used to provide inline documentation or a tl;dr for the notebook.  Also note that in Jupyter Lab the semantic headers can be used to generate an outline in the left sidebar!

# %% [markdown]
# ## Install packages
#
# Let's install some core packages we'll be using via `pip`

# %%
# !pip install numpy scipy seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 12.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached scipy-1.9.1-cp310-cp310-macosx_12_0_universal2.macosx_10_9_x86_64.whl (58.4 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.1/285.1 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 27.5 MB/s eta 0:00:00m eta 0:00:010:0101
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 28.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.6 MB/s eta 0:00:00
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 19.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 957.2/957.2 kB 16.0 MB/s eta 0:00:00m eta 0:00:01
# ...

# %% [markdown]
# ## Import numerical packages and play with some arrays

# %%
import numpy as np
import scipy as spi

x = np.random.standard_normal(10)
y = np.random.standard_normal(10)

display(x)
display(y)
# Out:
# array([ 1.66496859, -0.77942293,  0.71194353,  1.4850785 ,  0.48809259,
#         1.83095611,  0.0281015 , -1.63543066,  0.69920589,  0.93236825])
# array([ 0.01624175, -0.30395063, -1.10636851,  0.86332202, -0.33488837,
#         0.4608144 , -0.25981582, -0.09426253, -1.15226961,  0.7532163 ])

# %% [markdown]
# ## Visualize the values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(x)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(y)
# Out:
# <AxesSubplot:ylabel='Count'>
