# %% [markdown]
# # Introduce Jupyter Notebooks
#
# This is a normal Markdown cell, which is commonly used to provide inline documentation or a tl;dr for the notebook.  Also note that in Jupyter Lab the semantic headers can be used to generate an outline in the left sidebar!

# %% [markdown]
# ## Install packages
#
# Let's install some core packages we'll be using via `pip`

# %%
# !pip install numpy scipy seaborn
# Out:
# Collecting numpy
#   Downloading numpy-1.23.3-cp310-cp310-macosx_10_9_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 32.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting scipy
#   Downloading scipy-1.9.1-cp310-cp310-macosx_12_0_universal2.macosx_10_9_x86_64.whl (58.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 MB 28.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting seaborn
#   Downloading seaborn-0.12.0-py3-none-any.whl (285 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.1/285.1 kB 14.2 MB/s eta 0:00:00
# Collecting matplotlib>=3.1
#   Downloading matplotlib-3.5.3-cp310-cp310-macosx_10_9_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 42.1 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting pandas>=0.25
#   Downloading pandas-1.4.4-cp310-cp310-macosx_10_9_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 45.5 MB/s eta 0:00:00m eta 0:00:01:01:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rbates/src/adc2022-foss-ds-ml-tools/ENV/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (2.8.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/rbates/src/adc2022-foss-ds-ml-tools/ENV/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/rbates/src/adc2022-foss-ds-ml-tools/ENV/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (3.0.9)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.7 MB/s eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp310-cp310-macosx_10_10_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 35.4 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.2-py3-none-any.whl (959 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 47.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /Users/rbates/src/adc2022-foss-ds-ml-tools/ENV/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /Users/rbates/src/adc2022-foss-ds-ml-tools/ENV/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.1->seaborn) (1.16.0)
# Installing collected packages: pillow, numpy, kiwisolver, fonttools, cycler, scipy, pandas, matplotlib, seaborn
# Successfully installed cycler-0.11.0 fonttools-4.37.2 kiwisolver-1.4.4 matplotlib-3.5.3 numpy-1.23.3 pandas-1.4.4 pillow-9.2.0 scipy-1.9.1 seaborn-0.12.0

# %% [markdown]
# ## Import numerical packages and play with some arrays

# %%
import numpy as np
import scipy as spi

x = np.random.standard_normal(10)
y = np.random.standard_normal(10)

display(x)
display(y)
# Out:
# array([-2.0364862 , -0.57643073, -0.5984271 ,  1.49557312,  0.07757361,
#        -1.00297339,  0.18097809, -0.66786163, -0.0915515 ,  1.0161145 ])
# array([-0.98092635, -0.22886018,  0.70557472, -0.61987528, -0.99689603,
#         0.80824699, -0.77393052,  0.26931478,  0.51140653, -0.3693785 ])

# %% [markdown]
# ## Visualize the values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(x)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(y)
# Out:
# <AxesSubplot:ylabel='Count'>
