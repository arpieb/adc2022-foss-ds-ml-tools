# %% [markdown]
# # Introduce Pandas and DataFrames
#
# We're going to demonstrate how you can use the `pandas` package and its associated tools to process tabular data, analyze it, and visualize it.
#
# But first, let's install some additional packages!

# %%
# !pip install pandas-profiling pandas seaborn ipywidgets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.4/134.4 kB 2.6 MB/s eta 0:00:00m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.1/384.1 kB 9.1 MB/s eta 0:00:000:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 30.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...

# %% [markdown]
# ## Import pandas and load some data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load a CSV file from a URL, display head rows
df = pd.read_csv(
    'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
    names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Perform basic exploration

# %%
# Generate a table of descriptive statistics for the numeric columns
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %% [raw]
# # Display a basic plot of numeric values directly from pandas dataframe
# df.plot()
# plt.show()

# %% [markdown]
# ## Produce a data profiling report

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(df, title="Iris Profiling Report", explorative=True)
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.3.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-09-15 22:38:48.516472&quot;&gt;&lt;title&gt;Iris Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # Data visualizations

# %% [markdown]
# ## Basic visualization using Seaborn abstractions

# %%
import seaborn as sns

# Display a pairwise correlation plot of the numerical features, colored by their species
sns.pairplot(data=df, hue='species')
plt.show()
